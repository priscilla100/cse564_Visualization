# %%
import pandas as pd

# %%
df=pd.read_csv("df_merged.csv")
df.isna().sum()
# Out:
# Country              0
# Happiness Rank       0
# Ladder score         0
# Economy              0
# Social support       0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia Residual    0
# Year                 0
# Emoji                0
# Population           0
# Region               0
# Latitude             0
# Longitude            0
# dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['Europe', 'North America', 'Oceania', 'Asia', 'South America',
#        'Africa'], dtype=object)

# %%
df[['Region','Country']]
# Out:
#              Region           Country
# 0            Europe       Switzerland
# 1            Europe           Iceland
# 2            Europe           Denmark
# 3            Europe            Norway
# 4     North America            Canada
# ...             ...               ...
# 1505         Africa  Congo (Kinshasa)
# 1506         Africa      Sierra Leone
# 1507         Africa           Lesotho
# 1508           Asia           Lebanon
# 1509           Asia       Afghanistan
#
# [1510 rows x 2 columns]

# %%
df=pd.read_csv("merged_data.csv")

# %%
df
# Out:
#           Country                        Region  Happiness Rank  Ladder score  \
# 0         Finland                Western Europe               1         7.741
# 1         Denmark                Western Europe               2         7.583
# 2         Iceland                Western Europe               3         7.525
# 3          Sweden                Western Europe               4         7.344
# 4          Israel  Middle East and North Africa               5         7.341
# ..            ...                           ...             ...           ...
# 142      Zimbabwe            Sub-Saharan Africa             138         3.341
# 143  Sierra Leone            Sub-Saharan Africa             140         3.245
# 144       Lesotho            Sub-Saharan Africa             141         3.186
# 145       Lebanon  Middle East and North Africa             142         2.707
# 146   Afghanistan                    South Asia             143         1.721
#
#      Economy  Social support  Health  Freedom  Trust  Generosity  ...  \
# 0      1.844           1.572   0.695    0.859  0.546       0.142  ...
# 1      1.908           1.520   0.699    0.823  0.548       0.204  ...
# 2      1.881           1.617   0.718    0.819  0.182       0.258  ...
# 3      1.878           1.501   0.724    0.838  0.524       0.221  ...
# 4      1.803           1.513   0.740    0.641  0.193       0.153  ...
# ..       ...             ...     ...      ...    ...         ...  ...
# 142    0.748           0.850   0.232    0.487  0.131       0.096  ...
# 143    0.654           0.566   0.253    0.469  0.053       0.181  ...
# 144    0.771           0.851   0.000    0.523  0.085       0.082  ...
# 145    1.377           0.577   0.556    0.173  0.029       0.068  ...
# 146    0.628           0.000   0.242    0.000  0.088       0.091  ...
#
#       Latitude  Longitude Population  Percent_Population_aged_0_14  \
# 0    63.246778  25.920916        5.5                          15.0
# 1    55.670249  10.333328        5.9                          16.0
# 2    64.984182 -18.105901        0.4                          18.0
# 3    59.674971  14.520858       10.7                          17.0
# 4    30.812425  34.859476        9.3                          28.0
# ..         ...        ...        ...                           ...
# 142 -18.455496  29.746841       17.0                          40.0
# 143   8.640035 -11.840027        9.0                          38.0
# 144 -29.603927  28.335019        2.4                          34.0
# 145  40.375713 -76.462612        5.2                          27.0
# 146  33.768006  66.238514       43.4                          43.0
#
#      Percent_Population_aged_10_19  Percent_Population_aged_10_24  \
# 0                             11.0                           17.0
# 1                             11.0                           17.0
# 2                             13.0                           19.0
# 3                             12.0                           18.0
# 4                             17.0                           24.0
# ..                             ...                            ...
# 142                           24.0                           34.0
# 143                           23.0                           33.0
# 144                           21.0                           30.0
# 145                           20.0                           27.0
# 146                           24.0                           34.0
#
#      Percent_Population_aged_15_64  Percent_Population_aged_65_and_older  \
# 0                             61.0                                  24.0
# 1                             63.0                                  21.0
# 2                             66.0                                  16.0
# 3                             62.0                                  21.0
# 4                             60.0                                  12.0
# ..                             ...                                   ...
# 142                           57.0                                   3.0
# 143                           59.0                                   3.0
# 144                           62.0                                   4.0
# 145                           62.0                                  11.0
# 146                           55.0                                   2.0
#
#      LifeExpectancy_male  LifeExpectancy_female
# 0                   80.0                   85.0
# 1                   80.0                   84.0
# 2                   82.0                   85.0
# 3                   82.0                   85.0
# 4                   82.0                   85.0
# ..                   ...                    ...
# 142                 59.0                   65.0
# 143                 60.0                   63.0
# 144                 52.0                   58.0
# 145                 78.0                   82.0
# 146                 62.0                   68.0
#
# [147 rows x 23 columns]

# %%
df = pd.read_csv('imputed_dataset_with_coords.csv')
df.sample(5)
# Out:
#                   Country                              Region  Happiness Rank  \
# 1437              Moldova  Commonwealth of Independent States              71
# 920          Sierra Leone                  Sub-Saharan Africa             139
# 438   Congo (Brazzaville)                  Sub-Saharan Africa             124
# 1275               Cyprus                      Western Europe              46
# 1474             Pakistan                          South Asia             108
#
#       Ladder score   Economy  Social support    Health   Freedom     Trust  \
# 1437        5.8160  1.385000        1.277000  0.542000  0.695000  0.044000
# 920         3.9264  0.240560        0.747985  0.203954  0.382028  0.047941
# 438         4.2910  0.808964        0.832044  0.289957  0.435026  0.079618
# 1275        6.1300  1.824000        1.224000  0.580000  0.455000  0.050000
# 1474        4.6570  1.069000        0.600000  0.321000  0.542000  0.074000
#
#       Generosity  Dystopia Residual  Year Emoji   Latitude  Longitude
# 1437    0.077000           1.795000  2024     😑  47.287961  28.567094
# 920     0.257647           2.046272  2020     😡   8.640035 -11.840027
# 438     0.120852           1.724136  2017     😡  -0.726433  15.641915
# 1275    0.104000           1.893000  2023     🤩  34.917416  32.889903
# 1474    0.144000           1.907000  2024     😑  30.330840  71.247499

# %%
pop1522=pd.read_csv("pop2015_2022.csv")
pop1522
# Out:
#                          Country Country Code       2015       2016  \
# 0                          Aruba          ABW     104257     104874
# 1    Africa Eastern and Southern          AFE  600008424  616377605
# 2                    Afghanistan          AFG   33753499   34636207
# 3     Africa Western and Central          AFW  408690375  419778384
# 4                         Angola          AGO   28127721   29154746
# ..                           ...          ...        ...        ...
# 260                       Kosovo          XKX    1788196    1777557
# 261                  Yemen, Rep.          YEM   28516545   29274002
# 262                 South Africa          ZAF   55876504   56422274
# 263                       Zambia          ZMB   16248230   16767761
# 264                     Zimbabwe          ZWE   14154937   14452704
#
#           2017       2018       2019       2020       2021       2022
# 0       105439     105962     106442     106585     106537     106445
# 1    632746570  649757148  667242986  685112979  702977106  720859132
# 2     35643418   36686784   37769499   38972230   40099462   41128771
# 3    431138704  442646825  454306063  466189102  478185907  490330870
# 4     30208628   31273533   32353588   33428486   34503774   35588987
# ..         ...        ...        ...        ...        ...        ...
# 260    1791003    1797085    1788878    1790133    1786038    1761985
# 261   30034389   30790513   31546691   32284046   32981641   33696614
# 262   56641209   57339635   58087055   58801927   59392255   59893885
# 263   17298054   17835893   18380477   18927715   19473125   20017675
# 264   14751101   15052184   15354608   15669666   15993524   16320537
#
# [265 rows x 10 columns]

# %%
from fuzzywuzzy import process

# Function to find the closest match for a country name
def find_closest_match(country_name, population_data):
    matches = process.extract(country_name, population_data['Country'], limit=1)
    return matches[0][0] if matches and matches[0][1] > 70 else None


# Add population to the bigger table based on the year and country name
for index, row in df.iterrows():
    country_name = row['Country']
    year = row['Year']
    if pd.notnull(year):
        year = int(year)  # Convert to integer
        closest_match = find_closest_match(country_name, pop1522)
        if closest_match:
            population_col = str(year)
            if population_col in pop1522.columns:
                population = pop1522.loc[pop1522['Country'] == closest_match, population_col]
                if not population.empty:
                    df.at[index, 'Population'] = population.values[0]

df
# Out:
#                Country                        Region  Happiness Rank  \
# 0          Switzerland                Western Europe               1
# 1              Iceland                Western Europe               2
# 2              Denmark                Western Europe               3
# 3               Norway                Western Europe               4
# 4               Canada         North America and ANZ               5
# ...                ...                           ...             ...
# 1505  Congo (Kinshasa)            Sub-Saharan Africa             139
# 1506      Sierra Leone            Sub-Saharan Africa             140
# 1507           Lesotho            Sub-Saharan Africa             141
# 1508           Lebanon  Middle East and North Africa             142
# 1509       Afghanistan                    South Asia             143
#
#       Ladder score  Economy  Social support   Health  Freedom    Trust  \
# 0            7.587  1.39651         1.34951  0.94143  0.66557  0.41978
# 1            7.561  1.30232         1.40223  0.94784  0.62877  0.14145
# 2            7.527  1.32548         1.36058  0.87464  0.64938  0.48357
# 3            7.522  1.45900         1.33095  0.88521  0.66973  0.36503
# 4            7.427  1.32629         1.32261  0.90563  0.63297  0.32957
# ...            ...      ...             ...      ...      ...      ...
# 1505         3.295  0.53400         0.66500  0.26200  0.47300  0.07200
# 1506         3.245  0.65400         0.56600  0.25300  0.46900  0.05300
# 1507         3.186  0.77100         0.85100  0.00000  0.52300  0.08500
# 1508         2.707  1.37700         0.57700  0.55600  0.17300  0.02900
# 1509         1.721  0.62800         0.00000  0.24200  0.00000  0.08800
#
#       Generosity  Dystopia Residual  Year Emoji   Latitude   Longitude  \
# 0        0.29678            2.51738  2015     🤩  46.798562    8.231974
# 1        0.43630            2.70201  2015     🤩  64.984182  -18.105901
# 2        0.34139            2.49204  2015     🤩  55.670249   10.333328
# 3        0.34699            2.46531  2015     🤩  64.573154   11.528036
# 4        0.45811            2.45176  2015     🤩  61.066692 -107.991707
# ...          ...                ...   ...   ...        ...         ...
# 1505     0.18900            1.10200  2024     😡  -2.981434   23.822264
# 1506     0.18100            1.06800  2024     😡   8.640035  -11.840027
# 1507     0.08200            0.87500  2024     😡 -29.603927   28.335019
# 1508     0.06800           -0.07300  2024     😡  40.375713  -76.462612
# 1509     0.09100            0.67200  2024     😡  33.768006   66.238514
#
#        Population
# 0       8282396.0
# 1        330815.0
# 2       5683483.0
# 3       5188607.0
# 4      35702908.0
# ...           ...
# 1505          NaN
# 1506      50025.0
# 1507    2777979.0
# 1508    3990123.0
# 1509  341529256.0
#
# [1510 rows x 16 columns]

# %%
pop2322=pd.read_csv("pop2023-2024.csv")
pop2322
# Out:
#               Country          2024        2023
# 0               India  1.439665e+09  1428627663
# 1               China  1.425278e+09  1425671352
# 2       United States  3.415293e+08   339996563
# 3           Indonesia  2.794450e+08   277534122
# 4            Pakistan  2.444612e+08   240485658
# ..                ...           ...         ...
# 229        Montserrat           NaN        4386
# 230  Falkland Islands           NaN        3791
# 231              Niue  1.935000e+03        1935
# 232           Tokelau           NaN        1893
# 233      Vatican City           NaN         764
#
# [234 rows x 3 columns]

# %%
# Add population to the bigger table based on the year and country name
for index, row in df.iterrows():
    country_name = row['Country']
    year = row['Year']
    if pd.notnull(year):
        year = int(year)  # Convert to integer
        closest_match = find_closest_match(country_name, pop2322)
        if closest_match:
            population_col = str(year)
            if population_col in pop2322.columns:
                population = pop2322.loc[pop1522['Country'] == closest_match, population_col]
                if not population.empty:
                    df.at[index, 'Population'] = population.values[0]

df
# Out:
#                Country                        Region  Happiness Rank  \
# 0          Switzerland                Western Europe               1
# 1              Iceland                Western Europe               2
# 2              Denmark                Western Europe               3
# 3               Norway                Western Europe               4
# 4               Canada         North America and ANZ               5
# ...                ...                           ...             ...
# 1505  Congo (Kinshasa)            Sub-Saharan Africa             139
# 1506      Sierra Leone            Sub-Saharan Africa             140
# 1507           Lesotho            Sub-Saharan Africa             141
# 1508           Lebanon  Middle East and North Africa             142
# 1509       Afghanistan                    South Asia             143
#
#       Ladder score  Economy  Social support   Health  Freedom    Trust  \
# 0            7.587  1.39651         1.34951  0.94143  0.66557  0.41978
# 1            7.561  1.30232         1.40223  0.94784  0.62877  0.14145
# 2            7.527  1.32548         1.36058  0.87464  0.64938  0.48357
# 3            7.522  1.45900         1.33095  0.88521  0.66973  0.36503
# 4            7.427  1.32629         1.32261  0.90563  0.63297  0.32957
# ...            ...      ...             ...      ...      ...      ...
# 1505         3.295  0.53400         0.66500  0.26200  0.47300  0.07200
# 1506         3.245  0.65400         0.56600  0.25300  0.46900  0.05300
# 1507         3.186  0.77100         0.85100  0.00000  0.52300  0.08500
# 1508         2.707  1.37700         0.57700  0.55600  0.17300  0.02900
# 1509         1.721  0.62800         0.00000  0.24200  0.00000  0.08800
#
#       Generosity  Dystopia Residual  Year Emoji   Latitude   Longitude  \
# 0        0.29678            2.51738  2015     🤩  46.798562    8.231974
# 1        0.43630            2.70201  2015     🤩  64.984182  -18.105901
# 2        0.34139            2.49204  2015     🤩  55.670249   10.333328
# 3        0.34699            2.46531  2015     🤩  64.573154   11.528036
# 4        0.45811            2.45176  2015     🤩  61.066692 -107.991707
# ...          ...                ...   ...   ...        ...         ...
# 1505     0.18900            1.10200  2024     😡  -2.981434   23.822264
# 1506     0.18100            1.06800  2024     😡   8.640035  -11.840027
# 1507     0.08200            0.87500  2024     😡 -29.603927   28.335019
# 1508     0.06800           -0.07300  2024     😡  40.375713  -76.462612
# 1509     0.09100            0.67200  2024     😡  33.768006   66.238514
#
#        Population
# 0       8282396.0
# 1        330815.0
# 2       5683483.0
# 3       5188607.0
# 4      35702908.0
# ...           ...
# 1505          NaN
# 1506      50025.0
# 1507    2777979.0
# 1508    3990123.0
# 1509  341529256.0
#
# [1510 rows x 16 columns]

# %%
df.to_csv("merged_data_with_population.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv('merged_data_with_population.csv')

# %%
import pandas as pd
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# Read the datasets
continents_df = pd.read_csv("continents.csv")

# Assuming your dataframe is already loaded in a variable called 'df'

def fuzzy_match_continent(row):
    # Get the country name from the current row
    country = row['Country']

    # Define a threshold for a good match (e.g., 80% similarity)
    threshold = 80

    # Extract the best match from 'continents_df' based on country name
    matches = process.extractOne(country, continents_df['Country'], scorer=fuzz.partial_ratio)

    # Check if a match is found and above the threshold
    if matches and matches[1] >= threshold:
        return matches[0]  # Return the matched country name
    else:
        return None  # Return None if no good match found

# Apply fuzzy matching to each row in 'df'
df['Matched_Country'] = df.apply(fuzzy_match_continent, axis=1)

# Merge DataFrames based on the matched country
df_with_continent = df.merge(continents_df[['Country', 'Continent']], how='left', left_on='Matched_Country', right_on='Country')

# Drop the temporary 'Matched_Country' column (optional)
df_with_continent = df_with_continent.drop('Matched_Country', axis=1)


# Display the resulting DataFrame
df = df_with_continent

# %%
df.columns
# Out:
# Index(['Country_x', 'Region', 'Happiness Rank', 'Ladder score', 'Economy',
#        'Social support', 'Health', 'Freedom', 'Trust', 'Generosity',
#        'Dystopia Residual', 'Year', 'Emoji', 'Latitude', 'Longitude',
#        'Population', 'Country_y', 'Continent'],
#       dtype='object')

# %%
from fuzzywuzzy import process

# Read the longlat.csv file into a DataFrame
longlat_df = pd.read_csv("longlat.csv")

# Define a function for fuzzy matching
def fuzzy_match_country(name, choices):
    match = process.extractOne(name, choices)
    return match[0] if match[1] >= 80 else None

# Apply fuzzy matching to each country in df to find its closest match in longlat_df
df['Matched_Country'] = df['Country_x'].apply(lambda x: fuzzy_match_country(x, longlat_df['Country']))

# Merge the latitude and longitude columns from longlat_df to df based on the matched country names
df_merged = df.merge(longlat_df[['Country', 'Latitude', 'Longitude']], left_on='Matched_Country', right_on='Country', how='left')

# Drop the 'Matched_Country' column and the duplicate 'Country' column
df_merged = df_merged.drop(['Matched_Country', 'Country_y'], axis=1)

# Rename the 'Country_x' column to 'Country'
df_merged = df_merged.rename(columns={'Country_x': 'Country'})

# Display the resulting DataFrame
df_merged
# Out:
#                Country                        Region  Happiness Rank  \
# 0          Switzerland                Western Europe               1
# 1              Iceland                Western Europe               2
# 2              Denmark                Western Europe               3
# 3               Norway                Western Europe               4
# 4               Canada         North America and ANZ               5
# ...                ...                           ...             ...
# 1505  Congo (Kinshasa)            Sub-Saharan Africa             139
# 1506      Sierra Leone            Sub-Saharan Africa             140
# 1507           Lesotho            Sub-Saharan Africa             141
# 1508           Lebanon  Middle East and North Africa             142
# 1509       Afghanistan                    South Asia             143
#
#       Ladder score  Economy  Social support   Health  Freedom    Trust  \
# 0            7.587  1.39651         1.34951  0.94143  0.66557  0.41978
# 1            7.561  1.30232         1.40223  0.94784  0.62877  0.14145
# 2            7.527  1.32548         1.36058  0.87464  0.64938  0.48357
# 3            7.522  1.45900         1.33095  0.88521  0.66973  0.36503
# 4            7.427  1.32629         1.32261  0.90563  0.63297  0.32957
# ...            ...      ...             ...      ...      ...      ...
# 1505         3.295  0.53400         0.66500  0.26200  0.47300  0.07200
# 1506         3.245  0.65400         0.56600  0.25300  0.46900  0.05300
# 1507         3.186  0.77100         0.85100  0.00000  0.52300  0.08500
# 1508         2.707  1.37700         0.57700  0.55600  0.17300  0.02900
# 1509         1.721  0.62800         0.00000  0.24200  0.00000  0.08800
#
#       Generosity  Dystopia Residual  Year Emoji  Latitude_x  Longitude_x  \
# 0        0.29678            2.51738  2015     🤩   46.798562     8.231974
# 1        0.43630            2.70201  2015     🤩   64.984182   -18.105901
# 2        0.34139            2.49204  2015     🤩   55.670249    10.333328
# 3        0.34699            2.46531  2015     🤩   64.573154    11.528036
# 4        0.45811            2.45176  2015     🤩   61.066692  -107.991707
# ...          ...                ...   ...   ...         ...          ...
# 1505     0.18900            1.10200  2024     😡   -2.981434    23.822264
# 1506     0.18100            1.06800  2024     😡    8.640035   -11.840027
# 1507     0.08200            0.87500  2024     😡  -29.603927    28.335019
# 1508     0.06800           -0.07300  2024     😡   40.375713   -76.462612
# 1509     0.09100            0.67200  2024     😡   33.768006    66.238514
#
#        Population      Continent       Country  Latitude_y  Longitude_y
# 0       8282396.0         Europe   Switzerland   46.818188     8.227512
# 1        330815.0         Europe       Iceland   64.963051   -19.020835
# 2       5683483.0         Europe       Denmark   56.263920     9.501785
# 3       5188607.0         Europe        Norway   60.472024     8.468946
# 4      35702908.0  North America        Canada   56.130366  -106.346771
# ...           ...            ...           ...         ...          ...
# 1505  105085250.0         Africa   Congo [DRC]   -4.038333    21.758664
# 1506      50025.0         Africa  Sierra Leone    8.460555   -11.779889
# 1507    2777979.0         Africa       Lesotho  -29.609988    28.233608
# 1508    3990123.0           Asia       Lebanon   33.854721    35.862285
# 1509  341529256.0           Asia   Afghanistan   33.939110    67.709953
#
# [1510 rows x 20 columns]

# %%
df_merged.isna().sum()
# Out:
# Country               0
# Happiness Rank        0
# Ladder score          0
# Economy               0
# Social support        0
# Health                0
# Freedom               0
# Trust                 0
# Generosity            0
# Dystopia Residual     0
# Year                  0
# Emoji                 0
# Population            0
# Continent            17
# Country              16
# Latitude_y           16
# Longitude_y          16
# dtype: int64

# %%
df_merged = df_merged.drop(['Latitude_x','Longitude_x','Region'],axis=1)

# %%
df_merged.to_csv('df_merged.csv', index=False)

# %%
from fuzzywuzzy import process
import pandas as pd

# Sample dataframes
continents_data = pd.read_csv('continents.csv')

# Perform fuzzy matching to get the closest matching country names and add Continent based on the match
def match_country(name, choices):
    match = process.extractOne(name, choices)
    return match[1] if match[1] >= 80 else None

# df['Continent'] = df['Country'].apply(lambda x: match_country(x, continents_data['Country']))
df_with_continent = df.merge(continents_data[['Country', 'Continent']], how='left', on='Country')


df_with_continent.head(5)
# Out:
#        Country                 Region  Happiness Rank  Ladder score  Economy  \
# 0  Switzerland         Western Europe               1         7.587  1.39651
# 1      Iceland         Western Europe               2         7.561  1.30232
# 2      Denmark         Western Europe               3         7.527  1.32548
# 3       Norway         Western Europe               4         7.522  1.45900
# 4       Canada  North America and ANZ               5         7.427  1.32629
#
#    Social support   Health  Freedom    Trust  Generosity  Dystopia Residual  \
# 0         1.34951  0.94143  0.66557  0.41978     0.29678            2.51738
# 1         1.40223  0.94784  0.62877  0.14145     0.43630            2.70201
# 2         1.36058  0.87464  0.64938  0.48357     0.34139            2.49204
# 3         1.33095  0.88521  0.66973  0.36503     0.34699            2.46531
# 4         1.32261  0.90563  0.63297  0.32957     0.45811            2.45176
#
#    Year Emoji   Latitude   Longitude  Population      Continent
# 0  2015     🤩  46.798562    8.231974   8282396.0         Europe
# 1  2015     🤩  64.984182  -18.105901    330815.0         Europe
# 2  2015     🤩  55.670249   10.333328   5683483.0         Europe
# 3  2015     🤩  64.573154   11.528036   5188607.0         Europe
# 4  2015     🤩  61.066692 -107.991707  35702908.0  North America

# %%
df.isna().sum()
# Out:
# Country_x             0
# Region                0
# Happiness Rank        0
# Ladder score          0
# Economy               0
# Social support        0
# Health                0
# Freedom               0
# Trust                 0
# Generosity            0
# Dystopia Residual     0
# Year                  0
# Emoji                 0
# Latitude              0
# Longitude             0
# Population            0
# Country_y            17
# Continent            17
# dtype: int64
